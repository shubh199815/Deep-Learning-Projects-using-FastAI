# %% [markdown]
# <a href="https://colab.research.google.com/github/shubh199815/FastAI-DL-1/blob/master/PETS_fastai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from fastai.metrics import error_rate

# %%
bs = 64

# %%
help(untar_data)
# Out:
# Help on function untar_data in module fastai.datasets:
#
# untar_data(url:str, fname:Union[pathlib.Path, str]=None, dest:Union[pathlib.Path, str]=None, data=True, force_download=False) -> pathlib.Path
#     Download `url` to `fname` if it doesn't exist, and un-tgz to folder `dest`.

# %%
path = untar_data(URLs.PETS); path
# Out:
# PosixPath('/root/.fastai/data/oxford-iiit-pet')

# %%
path.ls()
# Out:
# [PosixPath('/root/.fastai/data/oxford-iiit-pet/annotations'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images')]

# %%
path_anno = path/'annotations'
path_img = path/'images'

# %%
fnames = get_image_files(path_img)
fnames[:5]
# Out:
# [PosixPath('/root/.fastai/data/oxford-iiit-pet/images/Egyptian_Mau_19.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/Maine_Coon_70.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/Maine_Coon_92.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/Persian_221.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/Bengal_73.jpg')]

# %%
help(np.random.seed())
# Out:
# Help on NoneType object:
#
# class NoneType(object)
#  |  Methods defined here:
#  |
#  |  __bool__(self, /)
#  |      self != 0
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).

# %%
np.random.seed(2)
pat = r'/([^/]+)_\d+.jpg$'

# %%
data = ImageDataBunch.from_name_re(path_img, fnames, pat, ds_tfms=get_transforms(), size=224, bs=bs).normalize(imagenet_stats)

# %%
data.show_batch(rows=3, figsize=(7,6))

# %%
# ?data.show_batch()

# %%
print(data.classes)
len(data.classes), data.c
# Out:
# ['Abyssinian', 'Bengal', 'Birman', 'Bombay', 'British_Shorthair', 'Egyptian_Mau', 'Maine_Coon', 'Persian', 'Ragdoll', 'Russian_Blue', 'Siamese', 'Sphynx', 'american_bulldog', 'american_pit_bull_terrier', 'basset_hound', 'beagle', 'boxer', 'chihuahua', 'english_cocker_spaniel', 'english_setter', 'german_shorthaired', 'great_pyrenees', 'havanese', 'japanese_chin', 'keeshond', 'leonberger', 'miniature_pinscher', 'newfoundland', 'pomeranian', 'pug', 'saint_bernard', 'samoyed', 'scottish_terrier', 'shiba_inu', 'staffordshire_bull_terrier', 'wheaten_terrier', 'yorkshire_terrier']
# (37, 37)

# %%
data.c
# Out:
# 37

# %%
# ?create_cnn()

# %%
# ?ConvLearner()
# Out:
# Object `ConvLearner` not found.

# %%
learn = create_cnn(data, models.resnet34, metrics = error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.torch/models/resnet34-333f7ec4.pth
# 87306240it [00:01, 57213513.12it/s]

# %%
learn.model
# Out:
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
learn.fit_one_cycle(4)
# Out:
# Total time: 08:25 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.417372</td>
#       <td>0.373999</td>
#       <td>0.112991</td>
#       <td>02:05</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.546078</td>
#       <td>0.261565</td>
#       <td>0.077131</td>
#       <td>02:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.328000</td>
#       <td>0.229491</td>
#       <td>0.071042</td>
#       <td>02:06</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.254881</td>
#       <td>0.227628</td>
#       <td>0.073748</td>
#       <td>02:06</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')

# %%
interp = ClassificationInterpretation.from_learner(learn)
losses, idxs = interp.top_losses()
len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
interp.plot_top_losses(9, figsize=(15, 11))

# %%
doc(interp.plot_top_losses)

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %%
# ?ClassificationInterpretation.from_learner()

# %%
interp.most_confused(min_val=2)
# Out:
# [('Egyptian_Mau', 'Bengal', 7),
#  ('Persian', 'Ragdoll', 6),
#  ('american_bulldog', 'staffordshire_bull_terrier', 5),
#  ('american_pit_bull_terrier', 'staffordshire_bull_terrier', 5),
#  ('beagle', 'basset_hound', 4),
#  ('miniature_pinscher', 'chihuahua', 4),
#  ('Bengal', 'Egyptian_Mau', 3),
#  ('British_Shorthair', 'Russian_Blue', 3),
#  ('Ragdoll', 'Birman', 3),
#  ('miniature_pinscher', 'american_pit_bull_terrier', 3),
#  ('yorkshire_terrier', 'havanese', 3),
#  ('Abyssinian', 'Bengal', 2),
#  ('Bengal', 'Abyssinian', 2),
#  ('Birman', 'Ragdoll', 2),
#  ('British_Shorthair', 'Ragdoll', 2),
#  ('Persian', 'Maine_Coon', 2),
#  ('basset_hound', 'beagle', 2),
#  ('havanese', 'yorkshire_terrier', 2),
#  ('pug', 'boxer', 2),
#  ('staffordshire_bull_terrier', 'american_pit_bull_terrier', 2)]

# %%
learn.unfreeze()

# %%
learn.load('stage-1')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (5912 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# Egyptian_Mau,Maine_Coon,Maine_Coon,Ragdoll,leonberger
# Path: /root/.fastai/data/oxford-iiit-pet/images;
#
# Valid: LabelList (1478 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# great_pyrenees,newfoundland,Siamese,British_Shorthair,german_shorthaired
# Path: /root/.fastai/data/oxford-iiit-pet/images;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
# ...

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(2, max_lr=slice(1e-6, 1e-4))
# Out:
# Total time: 04:23 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.218507</td>
#       <td>0.215484</td>
#       <td>0.065629</td>
#       <td>02:11</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.209987</td>
#       <td>0.212876</td>
#       <td>0.060893</td>
#       <td>02:11</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # New Section
